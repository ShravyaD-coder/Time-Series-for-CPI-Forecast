# %%
import warnings

import matplotlib as mpl
import numpy as np
import pandas as pd  # Basic library for all of our dataset operations
import statsmodels as sm
from matplotlib import pyplot as plt
from pylab import rcParams
from sklearn.linear_model import LinearRegression
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa import api as smt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv("D://RVCE//4th Year//SEM-8//Paper Demonstration//Urban Actuals.csv")
data=data.dropna()
data
# Out:
#            Date  Cereals and products  Meat and fish    Egg  \
# 0    01-01-2013                 110.5          109.1  113.0
# 1    01-02-2013                 112.9          112.9  116.9
# 2    01-03-2013                 113.9          111.4  113.2
# 3    01-04-2013                 114.6          113.4  106.0
# 4    01-05-2013                 115.4          114.2  102.7
# ..          ...                   ...            ...    ...
# 117  01-11-2022                 168.4          213.4  183.2
# 118  01-12-2022                 170.2          212.9  191.9
# 119  01-01-2023                 173.3          215.2  197.0
# 120  01-02-2023                 174.7          212.2  177.2
# 121  01-03-2023                 174.7          212.2  177.2
#
#      Milk and products  Oils and fats  Fruits  Vegetables  \
# 0                103.6          103.4   102.3       102.9
# 1                104.0          103.5   103.1       104.9
# 2                104.3          102.7   104.9       103.8
# ...

# %%
data.columns=data.columns.str.strip()
data.columns=data.columns.str.replace(" ","_")
data.columns
# Out:
# Index(['Date', 'Cereals_and_products', 'Meat_and_fish', 'Egg',
#        'Milk_and_products', 'Oils_and_fats', 'Fruits', 'Vegetables',
#        'Pulses_and_products', 'Sugar_and_Confectionery', 'Spices',
#        'Non-alcoholic_beverages', 'Prepared_meals,_snacks,_sweets_etc.',
#        'Food_and_beverages', 'Pan,_tobacco_and_intoxicants', 'Clothing',
#        'Footwear', 'Clothing_and_footwear', 'Housing', 'Fuel_and_light',
#        'Household_goods_and_services', 'Health', 'Transport_and_communication',
#        'Recreation_and_amusement', 'Education', 'Personal_care_and_effects',
#        'Miscellaneous', 'General_index'],
#       dtype='object')

# %%
data['Date']=pd.to_datetime(data['Date'],dayfirst=True)
data=data.set_index('Date')
data.head()
# Out:
#             Cereals_and_products  Meat_and_fish    Egg  Milk_and_products  \
# Date
# 2013-01-01                 110.5          109.1  113.0              103.6
# 2013-02-01                 112.9          112.9  116.9              104.0
# 2013-03-01                 113.9          111.4  113.2              104.3
# 2013-04-01                 114.6          113.4  106.0              104.7
# 2013-05-01                 115.4          114.2  102.7              105.5
#
#             Oils_and_fats  Fruits  Vegetables  Pulses_and_products  \
# Date
# 2013-01-01          103.4   102.3       102.9                105.8
# 2013-02-01          103.5   103.1       104.9                104.1
# 2013-03-01          102.7   104.9       103.8                103.5
# 2013-04-01          102.1   109.5       109.7                104.6
# 2013-05-01          101.5   110.6       123.7                105.2
#
#             Sugar_and_Confectionery  Spices  ...  Housing  Fuel_and_light  \
# ...

# %%
data_filtered=pd.DataFrame(data['Cereals_and_products'])
data_filtered
# Out:
#             Cereals_and_products
# Date
# 2013-01-01                 110.5
# 2013-02-01                 112.9
# 2013-03-01                 113.9
# 2013-04-01                 114.6
# 2013-05-01                 115.4
# ...                          ...
# 2022-11-01                 168.4
# 2022-12-01                 170.2
# 2023-01-01                 173.3
# 2023-02-01                 174.7
# 2023-03-01                 174.7
#
# [120 rows x 1 columns]

# %%
plt.plot(data_filtered,label='Cereals')
plt.title("Urban CPI of Cerelas")
plt.legend(loc="upper left")

# %%
from statsmodels.tsa.seasonal import seasonal_decompose


rcParams['figure.figsize'] = 18, 8
plt.figure(num=None, figsize=(50, 20), dpi=80, facecolor='w', edgecolor='k')
series = data_filtered
result = seasonal_decompose(series, model='mutiplicative',period=12)
result.plot();

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(data_filtered, lags=30); #q=10

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_pacf(data_filtered, lags=30, method='ywm'); #p=2

# %%
from statsmodels.tsa.stattools import adfuller

result=adfuller(data_filtered)
print("p-value: ",result[1])

result=adfuller(data_filtered.diff().dropna())
print("p-value: ",result[1])

result=adfuller(data_filtered.diff().diff().dropna())
print("p-value: ",result[1])
# Out:
# p-value:  0.9983290945993103
# p-value:  0.0027956600588599843
# p-value:  3.3203986878449952e-12

# %%
#train-test split


forecast_horizon=6
train=data_filtered[:'2022-09-01']
test=data_filtered['2022-10-01':]

#print(train)
print(test)
#print(train.shape())
#print(test.shape())
# Out:
#             Cereals_and_products
# Date
# 2022-10-01                 166.4
# 2022-11-01                 168.4
# 2022-12-01                 170.2
# 2023-01-01                 173.3
# 2023-02-01                 174.7
# 2023-03-01                 174.7

# %%
from pmdarima.arima import auto_arima
import pmdarima as pm

# %%
auto_arima=pm.auto_arima(train,stepwise=True, seasonal=True)
print(auto_arima.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  114
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -132.830
# Date:                Mon, 29 May 2023   AIC                            273.659
# Time:                        18:51:21   BIC                            284.569
# Sample:                             0   HQIC                           278.086
#                                 - 114
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1140      0.112      1.015      0.310      -0.106       0.334
# ar.L1          0.7947      0.143      5.541      0.000       0.514       1.076
# ma.L1         -0.5113      0.154     -3.328      0.001      -0.812      -0.210
# ...

# %%
y_pred=auto_arima.predict(forecast_horizon)
y_pred
# Out:
# D:\Anaconda\envs\major\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 114    166.547094
# 115    167.970150
# 116    169.215151
# 117    170.318645
# 118    171.309674
# 119    172.211324
# dtype: float64

# %%
data_copy=data_filtered.copy()
data_copy['ARIMA Manual']=[None]*len(train)+list(y_pred)
val=['Cereals_and_products','ARIMA Manual']
data_copy[val].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
import math

'''mape_12=mean_absolute_percentage_error(test,y_pred)*100
mae_12=mean_absolute_error(test,y_pred)
rmse_12=math.sqrt(mean_squared_error(test,y_pred))

print("12 Months")
print("mape: ",mape_12)
print("\nmae: ",mae_12)
print("\nrmse: ",rmse_12)
'''

mape_6=mean_absolute_percentage_error(test.head(6),y_pred.head(6))*100
mae_6=mean_absolute_error(test.head(6),y_pred.head(6))
rmse_6=math.sqrt(mean_squared_error(test.head(6),y_pred.head(6)))

print("\n6 Months")
print("mape: ",mape_6)
print("\nmae: ",mae_6)
print("\nrmse: ",rmse_6)
# Out:
# 6 Months
# mape:  1.0013062134791977
#
# mae:  1.7370249842026813
#
# rmse:  2.1506832368009494
